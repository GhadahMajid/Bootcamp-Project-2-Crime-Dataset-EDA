# %%
# !pip install pandas_profiling

# %% [markdown]
# ## importing the libraries and reading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp
from matplotlib import style

# %% [markdown]
# ## Initializing Visualization Set

# %%
plt.style.use('classic')

# %%
df = pd.read_csv('Crime.csv')
# Out:
# C:\Users\96655\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ## print first 5 rows

# %%
df.head()
# Out:
#    Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# 0    201219928         1204  180063894  12/21/2018 09:13:13 PM        120
# 1    201301798         5016  200035833  09/13/2020 12:26:58 AM        90Z
# 2    201221577         5404  190000342  01/03/2019 02:48:47 AM        90D
# 3    201221577         9053  190000342  01/03/2019 02:48:47 AM        90Z
# 4    201294935         2303  200027681  07/16/2020 05:29:50 PM        23C
#
#    Victims             Crime Name1                  Crime Name2  \
# 0        1  Crime Against Property                      Robbery
# 1        1   Crime Against Society           All Other Offenses
# 2        1   Crime Against Society  Driving Under the Influence
# 3        1                   Other           All Other Offenses
# 4        1  Crime Against Property                  Shoplifting
#
#                                   Crime Name3 Police District Name  ...  \
# ...

# %% [markdown]
# ## print number of rows and coloumns

# %%
print ("Number of rows:")
print(df.shape[0])
print("Number of columns:")
print (len(df.columns))
# Out:
# Number of rows:
# 318017
# Number of columns:
# 30

# %% [markdown]
# ## statistical describtion of numeric values

# %%
df.describe()
# Out:
#         Incident ID     CR Number        Victims       Zip Code  \
# count  3.180170e+05  3.180170e+05  318017.000000  314835.000000
# mean   2.012427e+08  1.711741e+08       1.022772   20876.510559
# std    8.965352e+04  6.169167e+07       0.193108     166.991320
# min    2.010871e+08  1.001107e+07       1.000000       6.000000
# 25%    2.011653e+08  1.705466e+08       1.000000   20853.000000
# 50%    2.012418e+08  1.900254e+08       1.000000   20878.000000
# 75%    2.013196e+08  2.100052e+08       1.000000   20904.000000
# max    2.013988e+08  3.300378e+08      22.000000   29882.000000
#
#        Address Number       Latitude      Longitude
# count    2.911460e+05  318017.000000  318017.000000
# mean     8.403602e+03      37.992356     -74.965807
# std      1.612727e+04       6.433814      12.693452
# min      1.000000e+00       0.000000     -77.516753
# 25%      1.600000e+03      39.019729     -77.197020
# 50%      8.100000e+03      39.072255     -77.098956
# ...

# %% [markdown]
# ## statistical describtion of categorical values

# %%
df.describe(include=['O'])
# Out:
#         Offence Code    Dispatch Date / Time NIBRS Code  \
# count         318017                  268850     318017
# unique           626                  245854         58
# top             2305  12/02/2019 04:39:39 PM        90Z
# freq           21244                      48      74889
#
#                    Crime Name1         Crime Name2          Crime Name3  \
# count                   317731              317731               317731
# unique                       5                  59                  336
# top     Crime Against Property  All Other Offenses  LARCENY - FROM AUTO
# freq                    146272               75407                27249
#
#        Police District Name             Block Address           City   State  \
# count                317924                    291046         316742  318017
# unique                    9                     21675             70      11
# top           SILVER SPRING  11100 BLK  VEIRS MILL RD  SILVER SPRING      MD
# ...

# %% [markdown]
# ## Is there a duplicate row?

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 318012    False
# 318013    False
# 318014    False
# 318015    False
# 318016    False
# Length: 318017, dtype: bool

# %% [markdown]
# ## Is there any missing values?

# %%
fig, ax = plt.subplots(figsize=(9,4))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
plt.title('The Missing Values Chart')
plt.xlabel('Atrributes',size=15)
plt.ylabel('# Nulss',size=15);
plt.show()

# %% [markdown]
# ## Drop irrelevant data

# %%
df = df.drop(columns=['CR Number','Offence Code','NIBRS Code','Dispatch Date / Time','Zip Code', 'Sector','Beat','PRA','Location','Street Prefix','Street Suffix','Address Number','Latitude','Longitude','Block Address','Crime Name3','Crime Name1'], axis=1)
df.head()
# Out:
#    Incident ID  Victims                  Crime Name2 Police District Name  \
# 0    201219928        1                      Robbery              WHEATON
# 1    201301798        1           All Other Offenses           GERMANTOWN
# 2    201221577        1  Driving Under the Influence            ROCKVILLE
# 3    201221577        1           All Other Offenses            ROCKVILLE
# 4    201294935        1                  Shoplifting           GERMANTOWN
#
#             City State Agency                               Place Street Name  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop     GEORGIA
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential    COLTRANE
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle     GRANDIN
# 3      ROCKVILLE    MD   RCPD                      Street - Other     GRANDIN
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store   FREDERICK
#
# ...

# %% [markdown]
# ## Filling the null values

# %%
df['End_Date_Time']=df['End_Date_Time'].fillna('countinued')

# %%
df['City']=df['City'].fillna(df['City'].mode()[0])

# %%
df['Street Type']=df['Street Type'].fillna(df['Street Type'].mode()[0])

# %%
fig, ax = plt.subplots(figsize=(9,4))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
plt.title('The Missing Values Chart')
plt.xlabel('Atrributes',size=15)
plt.ylabel('# Nulss',size=15);
plt.show()

# %% [markdown]
# ## The datafarme after filling the nulls

# %%
df.head()
# Out:
#    Incident ID  Victims                  Crime Name2 Police District Name  \
# 0    201219928        1                      Robbery              WHEATON
# 1    201301798        1           All Other Offenses           GERMANTOWN
# 2    201221577        1  Driving Under the Influence            ROCKVILLE
# 3    201221577        1           All Other Offenses            ROCKVILLE
# 4    201294935        1                  Shoplifting           GERMANTOWN
#
#             City State Agency                               Place Street Name  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop     GEORGIA
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential    COLTRANE
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle     GRANDIN
# 3      ROCKVILLE    MD   RCPD                      Street - Other     GRANDIN
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store   FREDERICK
#
# ...

# %%
df['Agency'].value_counts()
# Out:
# MCPD    274811
# GPD      17150
# RCPD     17073
# TPPD      8349
# MCFM       601
# MCSO        27
# OTHR         4
# P            2
# Name: Agency, dtype: int64

# %%
df['Agency'].unique()
# Out:
# array(['MCPD', 'RCPD', 'GPD', 'TPPD', 'MCFM', 'MCSO', 'OTHR', 'P'],
#       dtype=object)

# %%
df['State'].value_counts()
# Out:
# MD    317791
# 16       191
# DC        22
# VA         4
# ME         2
# MS         2
# 0          1
# 15         1
# ND         1
# MC         1
# 17         1
# Name: State, dtype: int64

# %%
df['Crime Name2'].value_counts()
# Out:
# All Other Offenses                             75407
# Theft From Motor Vehicle                       27249
# Drug/Narcotic Violations                       23594
# Simple Assault                                 21931
# Destruction/Damage/Vandalism of Property       19723
# Shoplifting                                    16968
# Driving Under the Influence                    15240
# All other Larceny                              14587
# Theft from Building                            11660
# Burglary/Breaking and Entering                  9073
# Identity Theft                                  9013
# Theft of Motor Vehicle Parts or Accessories     7231
# Motor Vehicle Theft                             6895
# False Pretenses/Swindle/Confidence Game         6700
# Liquor Law Violations                           6657
# Credit Card/Automatic Teller Machine Fraud      5073
# Disorderly Conduct                              5066
# Aggravated Assault                              4529
# ...

# %%
df['Year']=df['Start_Date_Time'].str.slice(6,10)
df
# Out:
#         Incident ID  Victims                  Crime Name2  \
# 0         201219928        1                      Robbery
# 1         201301798        1           All Other Offenses
# 2         201221577        1  Driving Under the Influence
# 3         201221577        1           All Other Offenses
# 4         201294935        1                  Shoplifting
# ...             ...      ...                          ...
# 318012    201397682        1           All Other Offenses
# 318013    201397752        1            All other Larceny
# 318014    201397766        1          Theft from Building
# 318015    201397789        1               Identity Theft
# 318016    201397815        1           Aggravated Assault
#
#        Police District Name           City State Agency  \
# 0                   WHEATON  SILVER SPRING    MD   MCPD
# 1                GERMANTOWN       DAMASCUS    MD   MCPD
# 2                 ROCKVILLE      ROCKVILLE    MD   RCPD
# ...

# %%
plt.bar(df['Year'].unique(),df['Year'].value_counts())
plt.title('crime frequency by the years')
plt.xlabel('Year Of Crime',size=15)
plt.ylabel('Number Of Crimes',size=15);

# %%
plt.pie(df['City'].value_counts(), labels=df['City'].unique(), explode=np.linspace(0.4,0.4,70));

# %% [markdown]
# ## pandas profiling

# %%
# profile = pp.ProfileReport(df)
# profile
