# %%
# !pip install pandas_profiling

# %% [markdown]
# ## importing the libraries and reading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling as pp
from matplotlib import style

# %% [markdown]
# ## Initializing Visualization Set

# %%
sns.set(rc= {'figure.figsize':(10,10)})

# %%
plt.style.use('bmh')

# %%
df = pd.read_csv('Crime.csv', dtype='unicode')

# %% [markdown]
# ## print first 5 rows

# %%
df.head()
# Out:
#   Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# 0   201219928         1204  180063894  12/21/2018 09:13:13 PM        120
# 1   201301798         5016  200035833  09/13/2020 12:26:58 AM        90Z
# 2   201221577         5404  190000342  01/03/2019 02:48:47 AM        90D
# 3   201221577         9053  190000342  01/03/2019 02:48:47 AM        90Z
# 4   201294935         2303  200027681  07/16/2020 05:29:50 PM        23C
#
#   Victims             Crime Name1                  Crime Name2  \
# 0       1  Crime Against Property                      Robbery
# 1       1   Crime Against Society           All Other Offenses
# 2       1   Crime Against Society  Driving Under the Influence
# 3       1                   Other           All Other Offenses
# 4       1  Crime Against Property                  Shoplifting
#
#                                   Crime Name3 Police District Name  ...  \
# 0                        ROBBERY - STREET-GUN              WHEATON  ...
# 1  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN  ...
# 2          DRIVING UNDER THE INFLUENCE LIQUOR            ROCKVILLE  ...
# 3                     LITTERING/TRASH DUMPING            ROCKVILLE  ...
# 4                       LARCENY - SHOPLIFTING           GERMANTOWN  ...
#
#   Street Prefix Street Name Street Suffix Street Type         Start_Date_Time  \
# 0           NaN     GEORGIA           NaN         AVE  12/21/2018 09:13:00 PM
# 1           NaN    COLTRANE           NaN          DR  08/08/2020 05:10:00 PM
# 2             N     GRANDIN           NaN         AVE  01/03/2019 02:48:00 AM
# 3             N     GRANDIN           NaN         AVE  01/03/2019 02:48:00 AM
# 4           NaN   FREDERICK           NaN          RD  07/16/2020 05:29:00 PM
#
#             End_Date_Time      Latitude      Longitude Police District Number  \
# 0                     NaN      39.03627       -77.0499                     4D
# 1  08/08/2020 12:00:00 AM      39.27784       -77.2115                     5D
# 2  01/03/2019 02:48:00 AM  39.086687641  -77.144753904                     1D
# 3  01/03/2019 02:48:00 AM  39.086687641  -77.144753904                     1D
# 4                     NaN    39.1982954    -77.2448997                     5D
#
#               Location
# 0  (39.0363, -77.0499)
# 1  (39.2778, -77.2115)
# 2  (39.0867, -77.1448)
# 3  (39.0867, -77.1448)
# 4  (39.1983, -77.2449)
#
# [5 rows x 30 columns]

# %% [markdown]
# ## print number of rows and coloumns

# %%
print ("Number of rows:")
print(df.shape[0])
print("Number of columns:")
print (len(df.columns))
# Out:
# Number of rows:
# 318017
# Number of columns:
# 30

# %%
df.shape
# Out:
# (318017, 30)

# %% [markdown]
# ## statistical describtion of numeric values

# %%
df.describe()
# Out:
#        Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# count       318017       318017     318017                  268850     318017
# unique      291886          342     291847                  245854         58
# top      201168542         2305  170550978  12/02/2019 04:39:39 PM        90Z
# freq             9        27249          9                      48      74889
#
#        Victims             Crime Name1         Crime Name2  \
# count   318017                  317731              317731
# unique      10                       5                  59
# top          1  Crime Against Property  All Other Offenses
# freq    312174                  146272               75407
#
#                 Crime Name3 Police District Name  ... Street Prefix  \
# count                317731               317924  ...         14250
# unique                  336                    9  ...             4
# top     LARCENY - FROM AUTO        SILVER SPRING  ...             E
# freq                  27249                66845  ...          5146
#
#        Street Name Street Suffix Street Type         Start_Date_Time  \
# count       318016          5455      317675                  318017
# unique        7812             7          32                  230055
# top        GEORGIA             W          RD  11/30/2019 12:00:00 PM
# freq         13882          3031       79076                      43
#
#                  End_Date_Time Latitude Longitude Police District Number  \
# count                   149774   318017    318017                 318017
# unique                  105316    45369     40111                     15
# top     12/02/2019 09:30:00 AM      0.0       0.0                     3D
# freq                        42     8863      8863                  66845
#
#           Location
# count       318017
# unique       34521
# top     (0.0, 0.0)
# freq          8863
#
# [4 rows x 30 columns]

# %% [markdown]
# ## statistical describtion of categorical values

# %%
df.describe(include=['O'])
# Out:
#        Incident ID Offence Code  CR Number    Dispatch Date / Time NIBRS Code  \
# count       318017       318017     318017                  268850     318017
# unique      291886          342     291847                  245854         58
# top      201168542         2305  170550978  12/02/2019 04:39:39 PM        90Z
# freq             9        27249          9                      48      74889
#
#        Victims             Crime Name1         Crime Name2  \
# count   318017                  317731              317731
# unique      10                       5                  59
# top          1  Crime Against Property  All Other Offenses
# freq    312174                  146272               75407
#
#                 Crime Name3 Police District Name  ... Street Prefix  \
# count                317731               317924  ...         14250
# unique                  336                    9  ...             4
# top     LARCENY - FROM AUTO        SILVER SPRING  ...             E
# freq                  27249                66845  ...          5146
#
#        Street Name Street Suffix Street Type         Start_Date_Time  \
# count       318016          5455      317675                  318017
# unique        7812             7          32                  230055
# top        GEORGIA             W          RD  11/30/2019 12:00:00 PM
# freq         13882          3031       79076                      43
#
#                  End_Date_Time Latitude Longitude Police District Number  \
# count                   149774   318017    318017                 318017
# unique                  105316    45369     40111                     15
# top     12/02/2019 09:30:00 AM      0.0       0.0                     3D
# freq                        42     8863      8863                  66845
#
#           Location
# count       318017
# unique       34521
# top     (0.0, 0.0)
# freq          8863
#
# [4 rows x 30 columns]

# %% [markdown]
# ## Drop irrelevant data

# %%
df = df.drop(columns=['CR Number','Offence Code','NIBRS Code','Dispatch Date / Time','Zip Code','Street Name', 'Sector','Beat','PRA','Location','Street Prefix','Street Suffix','Address Number','Latitude','Longitude','Block Address','Crime Name1'], axis=1)
df.head()
# Out:
#   Incident ID Victims                  Crime Name2  \
# 0   201219928       1                      Robbery
# 1   201301798       1           All Other Offenses
# 2   201221577       1  Driving Under the Influence
# 3   201221577       1           All Other Offenses
# 4   201294935       1                  Shoplifting
#
#                                   Crime Name3 Police District Name  \
# 0                        ROBBERY - STREET-GUN              WHEATON
# 1  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN
# 2          DRIVING UNDER THE INFLUENCE LIQUOR            ROCKVILLE
# 3                     LITTERING/TRASH DUMPING            ROCKVILLE
# 4                       LARCENY - SHOPLIFTING           GERMANTOWN
#
#             City State Agency                               Place Street Type  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop         AVE
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential          DR
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle         AVE
# 3      ROCKVILLE    MD   RCPD                      Street - Other         AVE
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store          RD
#
#           Start_Date_Time           End_Date_Time Police District Number
# 0  12/21/2018 09:13:00 PM                     NaN                     4D
# 1  08/08/2020 05:10:00 PM  08/08/2020 12:00:00 AM                     5D
# 2  01/03/2019 02:48:00 AM  01/03/2019 02:48:00 AM                     1D
# 3  01/03/2019 02:48:00 AM  01/03/2019 02:48:00 AM                     1D
# 4  07/16/2020 05:29:00 PM                     NaN                     5D

# %% [markdown]
# ## Is there a duplicate row?

# %%
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# ## Is there any missing values?

# %%
df.info(); #null: Crime Name2,Police District Name, Street Name
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             318017 non-null  object
#  1   Victims                 318017 non-null  object
#  2   Crime Name2             317731 non-null  object
#  3   Crime Name3             317731 non-null  object
#  4   Police District Name    317924 non-null  object
#  5   City                    316742 non-null  object
#  6   State                   318017 non-null  object
#  7   Agency                  318017 non-null  object
#  8   Place                   318017 non-null  object
#  9   Street Type             317675 non-null  object
#  10  Start_Date_Time         318017 non-null  object
#  11  End_Date_Time           149774 non-null  object
#  12  Police District Number  318017 non-null  object
# dtypes: object(13)
# memory usage: 31.5+ MB

# %%
df.isnull().sum()
# Out:
# Incident ID                    0
# Victims                        0
# Crime Name2                  286
# Crime Name3                  286
# Police District Name          93
# City                        1275
# State                          0
# Agency                         0
# Place                          0
# Street Type                  342
# Start_Date_Time                0
# End_Date_Time             168243
# Police District Number         0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(9,4))
sns.heatmap(df.isnull(), cbar=False, cmap="YlGnBu_r")
plt.title('The Missing Values Chart')
plt.xlabel('Atrributes',size=15)
plt.ylabel('# Nulss',size=15);
plt.show()

# %% [markdown]
# ## Dealing with null values

# %%
df.isnull().sum()
# Out:
# Incident ID                    0
# Victims                        0
# Crime Name2                  286
# Crime Name3                  286
# Police District Name          93
# City                        1275
# State                          0
# Agency                         0
# Place                          0
# Street Type                  342
# Start_Date_Time                0
# End_Date_Time             168243
# Police District Number         0
# dtype: int64

# %%
df = df[df['Crime Name2'].notna()]

# %%
df['Police District Name'].value_counts()
# Out:
# SILVER SPRING          66801
# WHEATON                59656
# MONTGOMERY VILLAGE     54628
# BETHESDA               44559
# ROCKVILLE              43080
# GERMANTOWN             40653
# CITY OF TAKOMA PARK     6405
# TAKOMA PARK             1603
# OTHER                    253
# Name: Police District Name, dtype: int64

# %%
df['Police District Name'] = df['Police District Name'].fillna('OTHER')

# %%
df = df[df['Crime Name2'].notna()]

# %%
df['City']=df['City'].fillna(df['City'].mode()[0])

# %%
df['Street Type']=df['Street Type'].fillna(df['Street Type'].mode()[0])

# %%
df.isnull().sum().sum()
# Out:
# 168067

# %% [markdown]
# ## The datafarme after dealing the nulls

# %%
df.head()
# Out:
#   Incident ID Victims                  Crime Name2  \
# 0   201219928       1                      Robbery
# 1   201301798       1           All Other Offenses
# 2   201221577       1  Driving Under the Influence
# 3   201221577       1           All Other Offenses
# 4   201294935       1                  Shoplifting
#
#                                   Crime Name3 Police District Name  \
# 0                        ROBBERY - STREET-GUN              WHEATON
# 1  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN
# 2          DRIVING UNDER THE INFLUENCE LIQUOR            ROCKVILLE
# 3                     LITTERING/TRASH DUMPING            ROCKVILLE
# 4                       LARCENY - SHOPLIFTING           GERMANTOWN
#
#             City State Agency                               Place Street Type  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop         AVE
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential          DR
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle         AVE
# 3      ROCKVILLE    MD   RCPD                      Street - Other         AVE
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store          RD
#
#           Start_Date_Time           End_Date_Time Police District Number
# 0  12/21/2018 09:13:00 PM                     NaN                     4D
# 1  08/08/2020 05:10:00 PM  08/08/2020 12:00:00 AM                     5D
# 2  01/03/2019 02:48:00 AM  01/03/2019 02:48:00 AM                     1D
# 3  01/03/2019 02:48:00 AM  01/03/2019 02:48:00 AM                     1D
# 4  07/16/2020 05:29:00 PM                     NaN                     5D

# %%
df['Agency'].value_counts()
# Out:
# MCPD    274572
# GPD      17140
# RCPD     17041
# TPPD      8344
# MCFM       601
# MCSO        27
# OTHR         4
# P            2
# Name: Agency, dtype: int64

# %%
df['Agency'].unique()
# Out:
# array(['MCPD', 'RCPD', 'GPD', 'TPPD', 'MCFM', 'MCSO', 'OTHR', 'P'],
#       dtype=object)

# %%
df['State'].value_counts()
# Out:
# MD    317505
# 16       191
# DC        22
# VA         4
# ME         2
# MS         2
# ND         1
# 0          1
# MC         1
# 17         1
# 15         1
# Name: State, dtype: int64

# %%
df['Crime Name2'].value_counts()
# Out:
# All Other Offenses                             75407
# Theft From Motor Vehicle                       27249
# Drug/Narcotic Violations                       23594
# Simple Assault                                 21931
# Destruction/Damage/Vandalism of Property       19723
# Shoplifting                                    16968
# Driving Under the Influence                    15240
# All other Larceny                              14587
# Theft from Building                            11660
# Burglary/Breaking and Entering                  9073
# Identity Theft                                  9013
# Theft of Motor Vehicle Parts or Accessories     7231
# Motor Vehicle Theft                             6895
# False Pretenses/Swindle/Confidence Game         6700
# Liquor Law Violations                           6657
# Credit Card/Automatic Teller Machine Fraud      5073
# Disorderly Conduct                              5066
# Aggravated Assault                              4529
# Trespass of Real Property                       4015
# Robbery                                         3715
# Runaway                                         3707
# Counterfeiting/Forgery                          3323
# Weapon Law Violations                           2381
# Drug Equipment Violations                       2013
# Impersonation                                   1608
# Forcible Rape                                   1439
# Fondling                                        1164
# Family Offenses, NonViolent                      800
# Pocket/picking                                   713
# Forcible Sodomy                                  615
# Forcible Fondling                                563
# Embezzlement                                     484
# Intimidation                                     437
# Purse-snatching                                  417
# Sexual Assault With An Object                    412
# Extortion/Blackmail                              406
# Arson                                            364
# Bad Checks                                       343
# Pornography/Obscene Material                     310
# Wire Fraud                                       288
# NOT NIBRS CODE                                   278
# Not Mapped                                       271
# Stolen Property Offenses                         229
# Prostitution                                     184
# Murder and Nonnegligent Manslaughter             121
# Peeping Tom                                      114
# Drunkenness                                      109
# Kidnapping/Abduction                              76
# From Coin/Operated Machine or Device              57
# Human Trafficking, Commercial Sex Acts            47
# Statuory Rape                                     35
# Curfew/Loitering/Vagrancy Violations              34
# Assisting or Promoting Prostitution               22
# Welfare Fraud                                     22
# Justifiable Homicide                              13
# Negligent Manslaughter                             2
# Human Trafficking, Involuntary Servitude           2
# Operating/Promoting/Assisting Gambling             1
# Bribery                                            1
# Name: Crime Name2, dtype: int64

# %%
df['Year']=df['Start_Date_Time'].str.slice(6,10)

# %%
df['Crime Time'] = pd.to_datetime(df['Start_Date_Time']).dt.hour

# %%
df['Crime Period'] =  df.apply(lambda row: 
                                 'Morning' if (row['Crime Time'] < 12) 
                                  else ('Afternoon' if row['Crime Time'] >= 12 and row['Crime Time'] <=16
                                  else 'Night'), axis=1)

# %%
df['Case File'] = df.apply(lambda row: 
                                 'Open' if (pd.isnull(row['End_Date_Time'])) 
                                  else 'Closed', axis=1)

# %%
df['Case File'].value_counts()
# Out:
# Open      168067
# Closed    149664
# Name: Case File, dtype: int64

# %%
df.drop(['Start_Date_Time','Crime Time','End_Date_Time'],axis=1, inplace = True)

# %%
df.head()
# Out:
#   Incident ID Victims                  Crime Name2  \
# 0   201219928       1                      Robbery
# 1   201301798       1           All Other Offenses
# 2   201221577       1  Driving Under the Influence
# 3   201221577       1           All Other Offenses
# 4   201294935       1                  Shoplifting
#
#                                   Crime Name3 Police District Name  \
# 0                        ROBBERY - STREET-GUN              WHEATON
# 1  OBSTRUCT GOVT - VIOLATION OF A COURT ORDER           GERMANTOWN
# 2          DRIVING UNDER THE INFLUENCE LIQUOR            ROCKVILLE
# 3                     LITTERING/TRASH DUMPING            ROCKVILLE
# 4                       LARCENY - SHOPLIFTING           GERMANTOWN
#
#             City State Agency                               Place Street Type  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop         AVE
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential          DR
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle         AVE
# 3      ROCKVILLE    MD   RCPD                      Street - Other         AVE
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store          RD
#
#   Police District Number  Year Crime Period Case File
# 0                     4D  2018        Night      Open
# 1                     5D  2020        Night    Closed
# 2                     1D  2019      Morning    Closed
# 3                     1D  2019      Morning    Closed
# 4                     5D  2020        Night      Open

# %% [markdown]
# ## Data Visualization

# %%
#1
plt.bar(df['Year'].unique(),df['Year'].value_counts())
plt.title('crime frequency by the years')
plt.xlabel('Year Of Crime',size=15)
plt.ylabel('Number Of Crimes',size=15);

# %%
#2
plt.pie(df['Police District Name'].value_counts(), labels=df['Police District Name'].unique(),  autopct='%.2f%%',  explode=[0,0,0,0,0,0,0,0.3,0.8])
plt.legend(loc="upper left");

# %%
#3
#count of crime group by type
group = df[['Victims', 'Crime Name2']].groupby('Crime Name2').count()
sns.heatmap(group);
plt.title("count of victims grouped by crime type");
plt.ylabel('Crimes');

# %%
#4
#Embezzlement crime on period (2020-2021-2022)
group =df[(df['Year'] =='2020')&(df['Crime Name2']=='Embezzlement')]
group = group[['Victims', 'Crime Name3']].groupby('Crime Name3').count()

group2 =df[(df['Year'] =='2021')&(df['Crime Name2']=='Embezzlement')]
group2 = group2[['Victims', 'Crime Name3']].groupby('Crime Name3').count()

group3 =df[(df['Year'] =='2022')&(df['Crime Name2']=='Embezzlement')]
group3 = group3[['Victims', 'Crime Name3']].groupby('Crime Name3').count()


plt.figure(figsize=(20,8))
#sns.countplot(x='Victims', data=group);

plt.plot(group['Victims'], linestyle = '--', linewidth = 3);
plt.plot(group2['Victims'], linestyle = '--', linewidth = 3);
plt.plot(group3['Victims'], linestyle = '--', linewidth = 3);

plt.legend(['2020','2021'], shadow = True, loc = 0);
plt.title("Embezzlement crime on period (2020-2021-2022)");
plt.xlabel('Embezzlement Crimes');
plt.ylabel('Sales');

# %%
#5 
#Abduction crimes in (2020-2021-2022)
group =df[(df['Year'] >='2020')&(df['Crime Name2']=='Kidnapping/Abduction')]
#
plt.figure(figsize=(20,8))
sns.histplot(
    group,
    x="Crime Name3",
    hue="Year",
    multiple="stack", 
    alpha=0.8)

plt.title("Abduction crimes in (2020-2021-2022)")
plt.xlabel('Abduction Crimes')
plt.ylabel('Incidents')
plt.xticks(rotation=90);

# %% [markdown]
# ## pandas profiling

# %%
# profile = pp.ProfileReport(df)
# profile
