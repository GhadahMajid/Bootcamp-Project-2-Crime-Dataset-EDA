# %%
import pandas as pd

# %%
df = pd.read_csv('Crime.csv')
df
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (1,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Incident ID Offence Code  CR Number    Dispatch Date / Time  \
# 0         201219928         1204  180063894  12/21/2018 09:13:13 PM
# 1         201301798         5016  200035833  09/13/2020 12:26:58 AM
# 2         201221577         5404  190000342  01/03/2019 02:48:47 AM
# 3         201221577         9053  190000342  01/03/2019 02:48:47 AM
# 4         201294935         2303  200027681  07/16/2020 05:29:50 PM
# ...             ...          ...        ...                     ...
# 318012    201397682         9199  220046742  10/25/2022 12:00:41 AM
# 318013    201397752         2316  220046795  10/25/2022 10:36:24 AM
# 318014    201397766         2308  220046615  10/24/2022 12:17:38 PM
# ...

# %%
df = df.drop(columns=['CR Number','Offence Code','NIBRS Code','Dispatch Date / Time','Zip Code', 'Sector','Beat','PRA','Location','Street Prefix','Street Suffix','Address Number','Latitude','Longitude','Block Address','Crime Name3','Crime Name1'], axis=1)
df.head()
# Out:
#    Incident ID  Victims                  Crime Name2 Police District Name  \
# 0    201219928        1                      Robbery              WHEATON
# 1    201301798        1           All Other Offenses           GERMANTOWN
# 2    201221577        1  Driving Under the Influence            ROCKVILLE
# 3    201221577        1           All Other Offenses            ROCKVILLE
# 4    201294935        1                  Shoplifting           GERMANTOWN
#
#             City State Agency                               Place Street Name  \
# 0  SILVER SPRING    MD   MCPD                   Street - Bus Stop     GEORGIA
# 1       DAMASCUS    MD   MCPD           Parking Lot - Residential    COLTRANE
# 2      ROCKVILLE    MD   RCPD                 Street - In vehicle     GRANDIN
# 3      ROCKVILLE    MD   RCPD                      Street - Other     GRANDIN
# 4     GERMANTOWN    MD   MCPD  Retail - Department/Discount Store   FREDERICK
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Incident ID             318017 non-null  int64
#  1   Victims                 318017 non-null  int64
#  2   Crime Name2             317731 non-null  object
#  3   Police District Name    317924 non-null  object
#  4   City                    316742 non-null  object
#  5   State                   318017 non-null  object
#  6   Agency                  318017 non-null  object
#  7   Place                   318017 non-null  object
#  8   Street Name             318016 non-null  object
#  9   Street Type             317675 non-null  object
#  10  Start_Date_Time         318017 non-null  object
#  11  End_Date_Time           149774 non-null  object
#  12  Police District Number  318017 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 31.5+ MB

# %%
df.isnull().sum()
# Out:
# Incident ID                    0
# Victims                        0
# Crime Name2                  286
# Police District Name          93
# City                        1275
# State                          0
# Agency                         0
# Place                          0
# Street Name                    1
# Street Type                  342
# Start_Date_Time                0
# End_Date_Time             168243
# Police District Number         0
# dtype: int64

# %%
df['Agency'].value_counts()
# Out:
# MCPD    274811
# GPD      17150
# RCPD     17073
# TPPD      8349
# MCFM       601
# MCSO        27
# OTHR         4
# P            2
# Name: Agency, dtype: int64

# %%
df['Agency'].unique()
# Out:
# array(['MCPD', 'RCPD', 'GPD', 'TPPD', 'MCFM', 'MCSO', 'OTHR', 'P'],
#       dtype=object)

# %%
df['State'].value_counts()
# Out:
# MD    317791
# 16       191
# DC        22
# VA         4
# ME         2
# MS         2
# ND         1
# 0          1
# MC         1
# 17         1
# 15         1
# Name: State, dtype: int64

# %%
df['Crime Name2'].value_counts()
# Out:
# All Other Offenses                             75407
# Theft From Motor Vehicle                       27249
# Drug/Narcotic Violations                       23594
# Simple Assault                                 21931
# Destruction/Damage/Vandalism of Property       19723
# Shoplifting                                    16968
# Driving Under the Influence                    15240
# All other Larceny                              14587
# Theft from Building                            11660
# Burglary/Breaking and Entering                  9073
# Identity Theft                                  9013
# Theft of Motor Vehicle Parts or Accessories     7231
# Motor Vehicle Theft                             6895
# False Pretenses/Swindle/Confidence Game         6700
# Liquor Law Violations                           6657
# Credit Card/Automatic Teller Machine Fraud      5073
# Disorderly Conduct                              5066
# Aggravated Assault                              4529
# ...
